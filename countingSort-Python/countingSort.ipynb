# %% [markdown]
# # Generacion de files txt

# %%
from random import randint
import json

u=100
numero_aleatorios = [randint(1,100) for _ in range(u)]
a = numero_aleatorios
with open('File_100.txt', 'w') as f:
    f.write(json.dumps(a))
u=500
numero_aleatorios = [randint(1,100) for _ in range(u)]
a = numero_aleatorios
with open('File_500.txt', 'w') as f:
    f.write(json.dumps(a))
u=1000
while u < 10000:

  if u>=1000 and u<10000:
    numero_aleatorios = [randint(1,100) for _ in range(u)]
    files="File_"
    num=str(u)
    ext=".txt"
    mi_path = files+num+ext
    with open(mi_path, 'w') as f:
      f.write(json.dumps(numero_aleatorios))
    f.close()
    numero_aleatorios=[]
  u=u+1000

while u <= 100000:
  if u>=10000 and u<=100000:
    numero_aleatorios = [randint(1,100) for _ in range(u)]
    files="File_"
    num=str(u)
    ext=".txt"
    mi_path = files+num+ext
    with open(mi_path, 'w') as f:
      f.write(json.dumps(numero_aleatorios))
    f.close()
    numero_aleatorios=[]
  u=u+10000

# %% [markdown]
# # ALgoritmo

# %%
# Python program for counting sort
# which takes negative numbers as well

# The function that sorts the given arr[]
def count_sort(arr):
	max_element = int(max(arr))
	min_element = int(min(arr))
	range_of_elements = max_element - min_element + 1
	# Create a count array to store count of individual
	# elements and initialize count array as 0
	count_arr = [0 for _ in range(range_of_elements)]
	output_arr = [0 for _ in range(len(arr))]

	# Store count of each character
	for i in range(0, len(arr)):
		count_arr[arr[i]-min_element] += 1

	# Change count_arr[i] so that count_arr[i] now contains actual
	# position of this element in output array
	for i in range(1, len(count_arr)):
		count_arr[i] += count_arr[i-1]

	# Build the output character array
	for i in range(len(arr)-1, -1, -1):
		output_arr[count_arr[arr[i] - min_element] - 1] = arr[i]
		count_arr[arr[i] - min_element] -= 1

	# Copy the output array to arr, so that arr now
	# contains sorted characters
	for i in range(0, len(arr)):
		arr[i] = output_arr[i]

	return arr


# Driver program to test above function
#arr = [-5, -10, 0, -3, 8, 5, -1, 10]
#ans = count_sort(arr)
#print("Sorted character array is " + str(ans))

# %% [markdown]
# # Ejecucion

# %%
import time
import json
u=100
countingSort_py=[]
ordenado=[]

files="File_"
ext=".txt"
while u<=500:
  num=str(u)
  mi_path = files+num+ext
  print(mi_path)
  with open(mi_path, 'r') as f:
      a = json.loads(f.read())
  print(len(a))
  #print(a)
  inicio = time.time()
  #ordenado.append(countingSort(a))
  ordenado.append(count_sort(a))
  fin = time.time()
  #print(ordenado)
  countingSort_py.append(round((fin-inicio),3))
  u=u+400

u=1000
while u <= 100000:
  num=str(u)
  mi_path = files+num+ext
  print(mi_path)
  with open(mi_path, 'r') as f:
      a = json.loads(f.read())
  print(len(a))
  #print(a)
  inicio = time.time()
  #ordenado.append(countingSort(a))
  ordenado.append(count_sort(a))
  fin = time.time()
  #print(ordenado)
  countingSort_py.append(round((fin-inicio),3))

  if u>=1000 and u<10000:
    u=u+1000
  elif u>=10000 and u<=100000:
    u=u+10000
# Out:
# File_100.txt
# 100
# File_500.txt
# 500
# File_1000.txt
# 1000
# File_2000.txt
# 2000
# File_3000.txt
# 3000
# File_4000.txt
# 4000
# File_5000.txt
# 5000
# File_6000.txt
# 6000
# File_7000.txt
# 7000
# File_8000.txt
# 8000
# File_9000.txt
# 9000
# File_10000.txt
# 10000
# File_20000.txt
# 20000
# File_30000.txt
# 30000
# File_40000.txt
# 40000
# File_50000.txt
# 50000
# File_60000.txt
# 60000
# File_70000.txt
# 70000
# File_80000.txt
# 80000
# File_90000.txt
# 90000
# File_100000.txt
# 100000

# %%
print(len(ordenado))
# Out:
# 21

# %% [markdown]
# # Plot

# %%
print(countingSort_py)
# Out:
# [0.0, 0.001, 0.001, 0.002, 0.002, 0.003, 0.004, 0.005, 0.006, 0.005, 0.006, 0.008, 0.007, 0.011, 0.014, 0.017, 0.021, 0.024, 0.028, 0.032, 0.039]

# %%
countingSort_cc=[0.004,0.006,0.011,0.038,0.026,0.036,0.042,0.049,0.055,0.063,0.07,0.085,0.161,0.236,0.317,0.386,0.475,0.541,0.626,0.702,0.826]
countingSort_py=[0.132, 0.545, 1.113, 1.832, 2.338, 1.705, 1.674, 2.102, 2.287, 2.908, 4.023, 4.094, 8.17, 11.93, 14.195, 17.524, 23.575, 25.051, 29.438, 33.759, 36.907]

# %%
print(countingSort_cc)
# Out:
# [0.004, 0.006, 0.011, 0.038, 0.026, 0.036, 0.042, 0.049, 0.055, 0.063, 0.07, 0.085, 0.161, 0.236, 0.317, 0.386, 0.475, 0.541, 0.626, 0.702, 0.826]

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(8,5))
x=["100","500","1000","2000","3000","4000","5000","6000","7000","8000","9000","10000","20000","30000","40000","50000","60000","70000","80000","90000","100000"]
plt.plot(countingSort_py, label = "Python")
plt.plot(countingSort_cc, label = "C++")
plt.legend()
plt.title('Tiempo de ejecución de countingSort en Python y C++')
plt.xlabel('Archivos')
plt.ylabel('Tiempo de ejecución en segundos')
plt.xticks(range(len(x)), x, rotation=45)
plt.savefig("countingSort.pdf")
plt.show()

# %% [markdown]
# # Brayan

# %%
InsertionSort_py=[0.026,0.021,0.178,0.557,1.139,1.440,2.266,3.306,4.470,5.853,6.712,9.400,31.185,71.457,149.016,221.151,306.917,548.756,740.777,1006.62,1347.39]
MergeSort_py=[0.067,0.105,0.130,0.321,0.668,0.960,1.523,1.934,2.644,3.505,3.976,5.220,18.700,52.504,85.973,125.59,192.68,284.19,386.52,552.31,725.03]
InsertionSort_cc=[0.082,0.194,0.339,0.659,0.961,1.276,1.693,1.902,2.248,2.546,2.886,3.212,6.373,9.506,13.270,16.510,18.720,24.100,28.490,34.510,35.550]
MergeSort_cc=[0.368,0.199,0.351,0.6484,1.007,1.305,1.599,1.962,2.159,2.745,2.828,3.157,6.283,8.853,13.110,14.700,17.660,21.530,24.020,27.000,29.910]

# %% [markdown]
# # Cristhian

# %%
QuickSort_c=[0.015,0.78,0.145,0.343,0.469,0.594,0.749,0.906,1.031,1.191,1.343,1.484,3,4.406,6.025,7.361,9.633,10.096,11.966,13.237,14.734]
QuickSort_py=[0.0, 0.010, 0.059, 0.09, 0.139, 0.18, 0.312, 0.624, 1.013, 1.247, 1.469, 2.468, 7.904, 14.605, 26.051, 42.94, 60.044, 82.719, 100.409, 129.401, 157.607]
HeapSort_c=[0.015, 0.063, 0.157, 0.343, 0.531, 0.641, 0.89, 0.922, 1.078, 1.218, 1.452, 1.531, 2.974, 4.421, 5.811, 7.545, 8.645, 10.111, 11.575, 12.872, 13.634]
HeapSort_py=[0.008, 0.0, 10.008, 10.003, 10.016, 10.031, 10.031, 10.066, 10.047, 10.062, 10.073, 10.083, 10.19, 10.313, 10.431, 10.525, 11.047, 10.847, 10.949, 11.069, 11.152]

# %% [markdown]
# # Juan

# %%
bubbleSort_py=[0.002, 0.038, 0.065, 0.231, 0.515, 0.953, 1.525, 2.204, 2.832, 3.961, 4.858, 6.221, 24.446, 54.465, 96.53, 153.61, 210.663, 319.982, 376.794, 507.685, 611.276]

selectionSort_py= [0.001, 0.016, 0.053, 0.101, 0.228, 0.403, 0.635, 0.883, 1.179, 1.569, 2.015, 2.422, 9.717, 21.756, 38.721, 61.365, 86.673, 119.499, 154.729, 200.887, 244.824]

selection_sort_c=[0,0,0.001,0.006,0.013,0.022,0.035,0.051,0.064,0.081,0.099,0.143,0.52,1.116,1.978,3.066,4.384,6.137,7.931,10.023,12.331]
Bubblesort_cc=[0,0,0.001,0.007,0.015,0.025,0.038,0.052,0.074,0.096,0.119,0.139,0.563,1.178,1.968,3.112,4.415,6.007,7.984,10.108,12.262]

# %% [markdown]
# # Honorio

# %%
countingSort_cc=[0.004,0.006,0.011,0.038,0.026,0.036,0.042,0.049,0.055,0.063,0.07,0.085,0.161,0.236,0.317,0.386,0.475,0.541,0.626,0.702,0.826]
countingSort_py=[0.0, 0.001, 0.001, 0.002, 0.002, 0.003, 0.004, 0.005, 0.006, 0.005, 0.006, 0.008, 0.007, 0.011, 0.014, 0.017, 0.021, 0.024, 0.028, 0.032, 0.039]

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(8,5))
x=["100","500","1000","2000","3000","4000","5000","6000","7000","8000","9000","10000","20000","30000","40000","50000","60000","70000","80000","90000","100000"]
plt.plot(countingSort_py, label = "countingSort")
plt.plot(QuickSort_py, label = "QuickSort")
plt.plot(HeapSort_py, label = "HeapSort")
plt.plot(InsertionSort_py, label = "InsertionSort")
plt.plot(MergeSort_py, label = "MergeSort")
plt.plot(bubbleSort_py, label = "bubbleSort")
plt.plot(selectionSort_py, label = "selectionSort")
plt.legend()
plt.title('Comparacion de los algoritmos de ordenamiento en Python')
plt.xlabel('Archivos')
plt.ylabel('Tiempo de ejecucióón')
plt.xticks(range(len(x)), x, rotation=45)
plt.savefig("comparacion_python.pdf")
plt.show()

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(8,5))
x=["100","500","1000","2000","3000","4000","5000","6000","7000","8000","9000","10000","20000","30000","40000","50000","60000","70000","80000","90000","100000"]
plt.plot(countingSort_cc, label = "countingSort")
plt.plot(QuickSort_c, label = "QuickSort")
plt.plot(HeapSort_c, label = "HeapSort")
plt.plot(InsertionSort_cc, label = "InsertionSort")
plt.plot(MergeSort_cc, label = "MergeSort")
plt.plot(Bubblesort_cc, label = "Bubblesort")
plt.plot(selection_sort_c, label = "Selectionsort")
plt.legend()
plt.title('Comparacion de los algoritmos de ordenamiento en C++.')
plt.xlabel('Archivos')
plt.ylabel('Tiempo de ejecución en segundos')
plt.xticks(range(len(x)), x, rotation=45)
plt.savefig("comparacion_algoritmos_c++.pdf")
plt.show()
